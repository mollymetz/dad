# %% [markdown]
# ## Exploring Data Homework
# - Load and describe dataset, variables, and variable types
# - Explore categorical features and quantitative features using basic measures of center and spread (.describe())
# - Filter categorical and quantitative features by logical criteria
# - Explore groups of categories using the .groupby() method.
# - Use .nlargest() and .nsmallest() to filter large and small values of interest

# %%
#Dataset for ratings of Japanese Hotels

# %%
import pandas as pd

# %%
japan = pd.read_csv('data/Hostel.csv')

# %%
japan
# Out:
#      Unnamed: 0                             hostel.name          City  \
# 0             1            "Bike & Bed" CharinCo Hostel         Osaka
# 1             2                            & And Hostel  Fukuoka-City
# 2             3                   &And Hostel Akihabara         Tokyo
# 3             4                        &And Hostel Ueno         Tokyo
# 4             5              &And Hostel-Asakusa North-         Tokyo
# 5             6                  1night1980hostel Tokyo         Tokyo
# 6             7                     328 Hostel & Lounge         Tokyo
# 7             8                                36Hostel     Hiroshima
# 8             9                3Q House - Asakusa Smile         Tokyo
# 9            10                        Ace Inn Shinjuku         Tokyo
# 10           11                        Air Osaka Hostel         Osaka
# 11           12                              Aizuya Inn         Tokyo
# ...

# %%
japan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 342 entries, 0 to 341
# Data columns (total 16 columns):
# Unnamed: 0       342 non-null int64
# hostel.name      342 non-null object
# City             342 non-null object
# price.from       342 non-null int64
# Distance         342 non-null object
# summary.score    327 non-null float64
# rating.band      327 non-null object
# atmosphere       327 non-null float64
# cleanliness      327 non-null float64
# facilities       327 non-null float64
# location.y       327 non-null float64
# security         327 non-null float64
# staff            327 non-null float64
# valueformoney    327 non-null float64
# lon              298 non-null float64
# lat              298 non-null float64
# dtypes: float64(10), int64(2), object(4)
# memory usage: 42.8+ KB

# %%
japan.groupby('City')['valueformoney'].count()
# Out:
# City
# Fukuoka-City     17
# Hiroshima        14
# Kyoto            73
# Osaka           101
# Tokyo           122
# Name: valueformoney, dtype: int64

# %%
city = japan.groupby('City')['valueformoney'].count()

# %%
city
# Out:
# City
# Fukuoka-City     17
# Hiroshima        14
# Kyoto            73
# Osaka           101
# Tokyo           122
# Name: valueformoney, dtype: int64

# %%
type(city)
# Out:
# pandas.core.series.Series

# %%
city.index
# Out:
# Index(['Fukuoka-City', 'Hiroshima', 'Kyoto', 'Osaka', 'Tokyo'], dtype='object', name='City')

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(city.index, city)
# Out:
# <BarContainer object of 5 artists>

# %%
japan.groupby('rating.band')['valueformoney'].count()
# Out:
# rating.band
# Fabulous     106
# Good          11
# Rating         8
# Superb       182
# Very Good     20
# Name: valueformoney, dtype: int64

# %%
rating = japan.groupby('rating.band')['valueformoney'].count()

# %%
plt.bar(rating, rating.index)
# Out:
# <BarContainer object of 5 artists>

# %%
japan.groupby('atmosphere')['valueformoney'].count().nlargest(5)
# Out:
# atmosphere
# 8.0     26
# 9.0     21
# 8.9     20
# 10.0    20
# 8.7     18
# Name: valueformoney, dtype: int64

# %%
japan.groupby('atmosphere')['valueformoney'].count().nsmallest(5)
# Out:
# atmosphere
# 2.7    1
# 4.8    1
# 5.3    1
# 5.4    1
# 5.5    1
# Name: valueformoney, dtype: int64

# %%
japan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 342 entries, 0 to 341
# Data columns (total 16 columns):
# Unnamed: 0       342 non-null int64
# hostel.name      342 non-null object
# City             342 non-null object
# price.from       342 non-null int64
# Distance         342 non-null object
# summary.score    327 non-null float64
# rating.band      327 non-null object
# atmosphere       327 non-null float64
# cleanliness      327 non-null float64
# facilities       327 non-null float64
# location.y       327 non-null float64
# security         327 non-null float64
# staff            327 non-null float64
# valueformoney    327 non-null float64
# lon              298 non-null float64
# lat              298 non-null float64
# dtypes: float64(10), int64(2), object(4)
# memory usage: 42.8+ KB

# %%
u5 = japan[japan['valueformoney'] <= 5]

# %%
u5.head()
# Out:
#      Unnamed: 0                     hostel.name   City  price.from  \
# 67           68                    Ezstay Osaka  Osaka        2000
# 272         273                    Qoo Ebisucho  Osaka        2000
# 280         281              Sakura Guest House  Osaka        2700
# 290         291  Shibamata FU-TEN Bed and Local  Tokyo        3000
#
#                     Distance  summary.score rating.band  atmosphere  \
# 67    4.6km from city centre            3.1      Rating         2.0
# 272   5.5km from city centre            5.7      Rating         6.0
# 280   4.3km from city centre            4.9      Rating         4.0
# 290  18.5km from city centre            4.9      Rating         2.0
#
#      cleanliness  facilities  location.y  security  staff  valueformoney  \
# 67           2.0         2.0         4.0       6.0    2.0            4.0
# 272          8.0         6.0         6.0       2.0    8.0            4.0
# ...

# %%
u5.nlargest(10, 'summary.score')
# Out:
#      Unnamed: 0                     hostel.name   City  price.from  \
# 272         273                    Qoo Ebisucho  Osaka        2000
# 280         281              Sakura Guest House  Osaka        2700
# 290         291  Shibamata FU-TEN Bed and Local  Tokyo        3000
# 67           68                    Ezstay Osaka  Osaka        2000
#
#                     Distance  summary.score rating.band  atmosphere  \
# 272   5.5km from city centre            5.7      Rating         6.0
# 280   4.3km from city centre            4.9      Rating         4.0
# 290  18.5km from city centre            4.9      Rating         2.0
# 67    4.6km from city centre            3.1      Rating         2.0
#
#      cleanliness  facilities  location.y  security  staff  valueformoney  \
# 272          8.0         6.0         6.0       2.0    8.0            4.0
# 280          4.0         4.0         8.0       4.0    6.0            4.0
# ...

# %%
japan.groupby('City')['price.from'].mean().sort_values(ascending = False).plot(kind = 'bar', title = 'Price by City')
